# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
df = pd.read_csv("C:/Datascience/train_mobile.csv")
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df['price_range'].unique()
# Out:
# array([1, 2, 3, 0])

# %% [markdown]
# Means that the column 'price_range' in the DataFrame contains four distinct categories:
#
# • 0 → Low price range
# • 1 → Medium price range
# • 2 → High price range
# • 3 → Very high price range
#
# These values are likely labels for classification, and  machine learning model
# is trained to predict one of these four classes based on mobile specifications.

# %%
x = df[['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']]

y = df['price_range']

# %%
# train/test split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# 🔹 What it means:
# • 80% of data goes to training (X_train, y_train)
# • 20% goes to testing (X_test, y_test)
# random_state=42 ensures the split is reproducible every time you run it

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)

# %%
knn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# 🔹 What it means:
# • Initializes a KNN classifier with 5 neighbors
# • Trains it on your training data (X_train, y_train)
# •The model will classify test samples based on the 5 closest training points

# %%
y_pred = knn_model.predict(x_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       105
#            1       0.92      0.93      0.93        91
#            2       0.89      0.91      0.90        92
#            3       0.97      0.94      0.95       112
#
#     accuracy                           0.94       400
#    macro avg       0.94      0.94      0.94       400
# weighted avg       0.94      0.94      0.94       400

# %% [markdown]
# 🔹 What it means:
# • Shows precision, recall, f1-score, and support for each class (0 to 3)
# • The model achieved 94% accuracy
# • Performance is strong across all price categories

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[103   2   0   0]
#  [  3  85   3   0]
#  [  0   5  84   3]
#  [  0   0   7 105]]

# %% [markdown]
# 🔹 What it means:
#
# • Rows = actual classes, columns = predicted classes
# • Diagonal values (103, 85, 84, 105) = correct predictions
# • Off-diagonal values = misclassifications
# • The model is performing well with minimal errors

# %%
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 94.25

# %%
df_test = pd.read_csv("C:/Datascience/test_mobile.csv")
df_test
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
df_test.columns
# Out:
# Index(['id', 'battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc',
#        'four_g', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
#        'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi'],
#       dtype='object')

# %%
df_test= df_test[['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
       'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
       'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
       'touch_screen', 'wifi']]

# %%
real_y = knn_model.predict(df_test)

# %%
import seaborn as sns
sns.histplot(real_y)
# Out:
# <Axes: ylabel='Count'>

# %%
real_y# Convert the NumPy array to a Pandas Series
pandas_series = pd.Series(real_y)

# Now, you can use value_counts() on the Pandas Series
counts = pandas_series.value_counts()

print(counts)
# Out:
# 2    258
# 0    256
# 3    255
# 1    231
# Name: count, dtype: int64

# %% [markdown]
# It counts how many times each class label appears in real_y.
# The result shows:
#
# • Class 0: 258 times
# • Class 1: 231 times
# • Class 2: 256 times
# • Class 3: 231 times

# %%
l =list(real_y)

# %%
print(l.count(0))
print(l.count(1))
print(l.count(2))
# Out:
# 256
# 231
# 258

# %% [markdown]
# It shows how many times each value appears in real_y:
#
# • 0 appears 256 times
# • 1 appears 231 times
# • 2 appears 258 times
